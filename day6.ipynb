# %% [markdown]
# # **List**

# %%
l=[1,4,56,7]

# %%
l[1]=3,5,{7}

# %%
l
# Out:
# [1, (3, 5, {7}), 56, 7]

# %%
l[1]=1

# %%
l
# Out:
# [1, 1, 56, 7]

# %%
l.append(2)

# %%
l
# Out:
# [1, 1, 56, 7, 2]

# %%
l.insert(2,8)

# %%
import sys
sys.getsizeof(l)
# Out:
# 120

# %%
l
# Out:
# [1, 1, 8, 1, 56, 7, 2]

# %%
l.pop()
# Out:
# 2

# %%
l
# Out:
# [1, 1, 8, 1, 56, 7]

# %%
l.pop(2)#2 is the index number
# Out:
# 8

# %%
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 l
#
# NameError: name 'l' is not defined

# %%
l.insert(2,(2,4,5,1))

# %%
l
# Out:
# [1, 1, (2, 4, 5, 1), 1, (2, 4, 5, 1), 56, 7]

# %%
l[2][2]
# Out:
# 5

# %% [markdown]
# # **List slicing**

# %%
j=[1,3,4,5,6,6,7,8,8,21]
j[1::2]
# Out:
# [3, 5, 6, 8, 21]

# %% [markdown]
# # **Input list from user**

# %%
list1=[]
n=int(input('Enter the index number'))
for i in range(n):
    new=(input())
    list1.insert(i,new)

print(list1)
# Out:
# Enter the index number 5
#  1
#  W
#  2
#  4
#  1
# ['1', 'W', '2', '4', '1']

# %%
from IPython.display import Image
Image('list_functions.png')

# %% [markdown]
# # **Use of Copy()**

# %%
l
l1=l.copy()
l2=l

# %%
l
# Out:
# [1, 1, (2, 4, 5, 1), 1, (2, 4, 5, 1), 56, 7]

# %%
l1
# Out:
# [1, 1, (2, 4, 5, 1), 1, (2, 4, 5, 1), 56, 7]

# %%
l2
# Out:
# [1, 1, (2, 4, 5, 1), 1, (2, 4, 5, 1), 56, 7]

# %%
l[2]=120

# %%
l
# Out:
# [1, 1, 120, 1, (2, 4, 5, 1), 56, 7]

# %%
l1 #l1 is not updated
# Out:
# [1, 1, (2, 4, 5, 1), 1, (2, 4, 5, 1), 56, 7]

# %%
l2 #l2 updated as l was updated
# Out:
# [1, 1, 120, 1, (2, 4, 5, 1), 56, 7]

# %% [markdown]
# # **Use of extend()**

# %%
h={2,4,5}

# %%
l.extend(h)# adds all elemnts of h in different index

# %%
l
# Out:
# [1, 1, 120, 1, (2, 4, 5, 1), 56, 7, 2, 4, 5]

# %%
l.append(h)#adds all elements in single index

# %%
l
# Out:
# [1, 1, 120, 1, (2, 4, 5, 1), 56, 7, 2, 4, 5, {2, 4, 5}]

# %% [markdown]
# # **index()**

# %%
l.index((2, 4, 5, 1))#It finds index numbers
# Out:
# 4

# %%
l.count(2)
# Out:
# 1

# %%
l.count(1)
# Out:
# 3

# %% [markdown]
# # **sort() and revese()**

# %%
l.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 l.sort()
#
# TypeError: '<' not supported between instances of 'tuple' and 'int'

# %%
lo=[254,3,5,6,1,4,634,2,36]
lo.sort()

# %%
lo.sort()

# %%
lo
# Out:
# [1, 2, 3, 4, 5, 6, 36, 254, 634]

# %%
lo.reverse()

# %%
lo
# Out:
# [634, 254, 36, 6, 5, 4, 3, 2, 1]

# %%
lo.remove(36)#removes the direct element

# %%
lo
# Out:
# [634, 254, 6, 5, 4, 3, 2, 1]

# %% [markdown]
# # **pop()**

# %%
lo.pop(2)#removes the element by index number
# Out:
# 6

# %%
lo
# Out:
# [1, 2, 3, 4, 5, 6, 36, 254, 634]

# %%
del lo[-2] #del is not a datatype, its a keyword

# %%
lo
# Out:
# [1, 2, 3, 4, 5, 6, 36, 634]

# %% [markdown]
# # **clear()**

# %%
lo.clear()

# %%
lo
# Out:
# []

# %% [markdown]
# # **List Comprehension**

# %%
from IPython.display import Image
Image('List_comprehension.png')

# %%
f=[x**2 for x in range(10) if x%2==0]

# %%
f
# Out:
# [0, 4, 16, 36, 64]

# %%
data='I love data science'
data=data.split()
x=[x for x in data if x!='I']

# %%
x
# Out:
# ['love', 'data', 'science']

# %%
matrix=[[x for x in range(1,4)] for j in range(3)] # for j in range(3) eita outer loop.......x for x in range(1,4) eita inner loop

# %%
matrix
# Out:
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]

# %% [markdown]
# # **Using function in List Comprehension**

# %%
lists=['saikat','s','f','g','fdf','ewrew']
    
extract=[len(x) for x in lists]
print(extract)
# Out:
# [6, 1, 1, 1, 3, 5]

# %%
lists[0]
# Out:
# 'saikat'

# %%
extract
# Out:
# [6, 1, 1, 1]

# %% [markdown]
# # **tuple**

# %%
tup=('saikat',1,2,'3saika')

# %%
type(tup)
# Out:
# tuple

# %%
tup=('saolat')

# %%
type(tup)
# Out:
# str

# %%
tup1=('saikat',)#ekta comma dilei seta tuple hoye jabe

# %%
type(tup1)
# Out:
# tuple

# %%
s=list(tup1)#converting tuple into list

# %%
s
# Out:
# ['saikat']

# %%
type(s)
# Out:
# list

# %%
s.append('Muntasir')

# %%
s
# Out:
# ['saikat', 'Muntasir']

# %%
q=tuple(s)#converting list into tuple

# %%
type(q)
# Out:
# tuple

# %%
tup4= 1,4,5,'saikat','Tanvir'# kono paranthesis na dileo seta tuple bujay

# %%
tup4
# Out:
# (1, 4, 5, 'saikat', 'Tanvir')

# %% [markdown]
# # **tuple concatenation**

# %%
tup4+q
# Out:
# (1, 4, 5, 'saikat', 'Tanvir', 'saikat', 'Muntasir')

# %% [markdown]
# # **tuple multiplication**

# %%
tup4
# Out:
# (1, 4, 5, 'saikat', 'Tanvir')

# %%
j=tup4*2

# %%
j
# Out:
# (1, 4, 5, 'saikat', 'Tanvir', 1, 4, 5, 'saikat', 'Tanvir')

# %%
'Tanvir' in j
# Out:
# True

# %%
'Saikat' in j
# Out:
# False

# %%
del tup4[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[222], line 1
# ----> 1 del tup4[2]
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# # **Set**

# %%
# Set er kono indexing nai...
# Set er vetor mutable elements like Lists,set,dictionaries egulo rakha jabena
# Set same value multiple times rakhte parena

# %%
set1={2,1,4,'Taki',(2,4,1)}

# %%
set1
# Out:
# {(2, 4, 1), 1, 2, 4, 'Taki'}

# %%
set1.add(1)

# %%
set1
# Out:
# {(2, 4, 1), 1, 2, 4, 'Taki'}

# %%
set1.update([2,4,5,1])#adding multiple elements

# %%
set1
# Out:
# {(2, 4, 1), 1, 123, 2, 4, 5, 54, 'Taki'}

# %%
set1.remove(1)

# %%
set1
# Out:
# {(2, 4, 1), 2, 4, 5, 'Taki'}

# %%
2 in set1#checking membership
# Out:
# True

# %%
set2={2,4,4,1}

# %%
set2
# Out:
# {1, 2, 4}

# %%
set2.pop()
# Out:
# 1

# %%
set2
# Out:
# {2, 4}
