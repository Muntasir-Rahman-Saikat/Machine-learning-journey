# %%
#Numeric Data 

x = 10 #int
y = 10.5 #float
z = 10+5j #10 is real number and 5j is imaginary

type(x)


type(y)


type(z)



isinstance(z,complex)


#isinstance(10,float)
# Out:
# True

# %%
x=int(input('enter ther first value'))
# Out:
# enter ther first value 45

# %%
x
# Out:
# 45

# %%
y=int(x)

# %%
y
# Out:
# 45

# %% [markdown]
# # **Bool**

# %%
p=True
y=False

# %%
p
y
# Out:
# False

# %% [markdown]
# # ***Sequence Data***

# %% [markdown]
# # **list**

# %%
l=([2, 4, 5, 6, 'Data',(2,4,5,4)]) #list mutable

# %%
l
# Out:
# [2, 4, 5, 6, 'Data', (2, 4, 5, 4)]

# %%
l[3]
# Out:
# 6

# %%
l[-1][-2]
# Out:
# 5

# %%
isinstance(l,list)
# Out:
# True

# %%
l.insert(0,6)
print(l)
# Out:
# [6, 2, 4, 5, 6, 'Data', (2, 4, 5, 4)]

# %%
isinstance(l,tuple)
# Out:
# False

# %%
h=[2,4,5,1]

# %%
type(h)
# Out:
# list

# %% [markdown]
# # **tuple**

# %%
t=(1,4,5,6,8) #tuple immutable
t[0:4:2]

# %%
t[0:4:2]
# Out:
# (1, 5)

# %% [markdown]
# # **array**

# %%
import array as ar 
a=ar.array('i',[255,4,5,6])

# %%
b=ar.array('f',[2.4,4,5,23])

# %%
a.insert(3,2)
b.insert(2,78)

# %%
a
b
# Out:
# array('f', [2.4000000953674316, 4.0, 78.0, 5.0, 23.0])

# %%
type(a)
# Out:
# array.array

# %%
x='''
I Love data 
Sciecne
'''

# %%
x
# Out:
# '\nI Love data \nSciecne\n'

# %% [markdown]
# # **set**

# %%
s={3,2,5,1}

# %%
s
# Out:
# {1, 2, 3, 5}

# %%
type(s)
# Out:
# set

# %% [markdown]
# # **dictionary**

# %%
 dic={ 
    'versity': 'CUET',
  'subject': 'EEE' 
}

# %%
dic
# Out:
# {'versity': 'CUET', 'subject': 'EEE'}

# %%
practice={
    'versity':'Massacuets',
    'subject':'data science'
}

# %%
practice.values()
# Out:
# dict_values(['Massacuets', 'data science'])

# %%
type(dic)
# Out:
# dict

# %%
dic.keys()
# Out:
# dict_keys(['versity', 'subject'])

# %%
dic.values()
# Out:
# dict_values(['CUET', 'EEE'])

# %% [markdown]
# # **data frame**

# %%
import pandas as pd
df=pd.read_excel(r'E:\Cuet\python\stepresponsekp1.xlsx')

# %%
df.head(100)
# Out:
#     TimeStamp  Reference  Position  Speed   Current  Voltage     Error  \
# 0        5.01   0.001526      -6.7    0.0 -0.187118      0.0  8.659495
# 1        5.02   0.001526      -6.7    0.0 -0.141058      0.0  8.659495
# 2        5.03   0.001526      -6.7    0.0 -0.158330      0.0  8.659495
# 3        5.04   0.001526      -6.7    0.0 -0.123786      0.0  8.659495
# 4        5.05   0.001526      -6.7    0.0 -0.141058      0.0  8.659495
# ..        ...        ...       ...    ...       ...      ...       ...
# 95       5.96   0.001526      -6.7    0.0 -0.141058      0.0  8.659495
# 96       5.97   0.001526      -6.7    0.0 -0.187118      0.0  8.659495
# 97       5.98   0.001526      -6.7    0.0 -0.141058      0.0  8.659495
# 98       5.99   0.001526      -6.7    0.0 -0.187118      0.0  8.659495
# 99       6.00   0.001526      -6.7    0.0 -0.195754      0.0  8.659495
#
#     Kp x Error  Error Sum / Ti  Td x Delta Err.  PID Output
# ...

# %%
import pandas as lk
fd=lk.read_csv(r'E:\Cuet\level-4 term-2\theisi\7d09c677-134f-49ae-8128-6bc00784967a\7d09c677-134f-49ae-8128-6bc00784967a\data\barnground_june.dat',delim_whitespace=True,on_bad_lines='skip',header=None)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15940\2883087100.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   fd=lk.read_csv(r'E:\Cuet\level-4 term-2\theisi\7d09c677-134f-49ae-8128-6bc00784967a\7d09c677-134f-49ae-8128-6bc00784967a\data\barnground_june.dat',delim_whitespace=True,on_bad_lines='skip',header=None)

# %%
valid_data = []

with open(r'E:\Cuet\level-4 term-2\theisi\7d09c677-134f-49ae-8128-6bc00784967a\7d09c677-134f-49ae-8128-6bc00784967a\data\barnground_june.dat') as file:
    lines = file.readlines()

# Step 1: Skip the first and last 7 lines
middle_lines = lines[7:-7]

# Step 2: Filter rows with exactly 3 values (columns)
for line in middle_lines:
    parts = line.strip().split()
    if len(parts) == 3:
        valid_data.append(parts)

# Optional: Convert to pandas DataFrame
import pandas as pd
df = pd.DataFrame(valid_data, columns=['Col1', 'Col2', 'Col3'])

# If needed, convert data to numeric
df = df.apply(pd.to_numeric, errors='coerce')

print(df.head(20))
# Out:
#     Col1  Col2       Col3
# 0    0.5   0.2  111.31350
# 1    0.7   0.2   92.15196
# 2    0.9   0.2   81.99750
# 3    1.1   0.2   51.56817
# 4    1.3   0.2   76.48504
# 5    1.5   0.2   65.25031
# 6    1.7   0.2   47.95465
# 7    1.9   0.2   64.86559
# 8    2.1   0.2   49.85733
# 9    2.3   0.2  126.14190
# 10   2.5   0.2   79.78323
# 11   2.7   0.2   70.08631
# 12   2.9   0.2   98.19398
# 13   3.1   0.2   80.98268
# 14   3.3   0.2   87.07843
# 15   3.5   0.2   64.92401
# 16   3.7   0.2   43.01462
# 17   3.9   0.2  129.44990
# 18   4.1   0.2   86.07240
# 19   4.3   0.2   88.68572

# %%
parts
# Out:
# ['16.6', '1.6', '101.7937']

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\User\Downloads\60 days of python

# %%
df.shape
# Out:
# (1590, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1590 entries, 0 to 1589
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   TimeStamp        1590 non-null   float64
#  1   Reference        1590 non-null   float64
#  2   Position         1590 non-null   float64
#  3   Speed            1590 non-null   float64
#  4   Current          1590 non-null   float64
#  5   Voltage          1590 non-null   float64
#  6   Error            1590 non-null   float64
#  7   Kp x Error       1590 non-null   float64
#  8   Error Sum / Ti   1590 non-null   float64
#  9   Td x Delta Err.  1590 non-null   float64
#  10  PID Output       1590 non-null   float64
# dtypes: float64(11)
# memory usage: 136.8 KB

# %% [markdown]
# # **binary types**

# %%
byte_arr=bytearray('ABCDEF','utf-8')

# %%
type(byte_arr)
# Out:
# bytearray

# %%
byte_arr
# Out:
# bytearray(b'ABCDEF')

# %%
memoryview(byte_arr)

# %%
memoryview(byte_arr)[0]
# Out:
# 65

# %%
memoryview(byte_arr)[0]=98

# %%
memoryview(byte_arr)[0]
# Out:
# 98

# %%
byte_arr
# Out:
# bytearray(b'bBCDEF')

# %% [markdown]
# # **identity operators**

# %%
x=1001
y=1001

# %%
x is y #different memory location
# Out:
# False

# %%
x is not y
# Out:
# True

# %%
 2**3
# Out:
# 8

# %%
4//3
# Out:
# 1

# %%
4\\3
# Out:
#   Cell In[28], line 1
#     4\\3
#       ^
# SyntaxError: unexpected character after line continuation character

# %%
4/3
# Out:
# 1.3333333333333333

# %%
import math
math.ceil(4/3)
# Out:
# 2

# %% [markdown]
# # **Membership Operator**

# %%
list=[1,2,4,56,3]
1 in list
# Out:
# True

# %%
10 in list
# Out:
# False

# %%
10 not in list
# Out:
# True

# %%
s='Learn Data Science'

# %%
'data' in s
# Out:
# False

# %%
'Data' in s
# Out:
# True

# %% [markdown]
# # **Bitwise operator**

# %%
x= 1010#10
y= o0101#5
x | y = 1111
x & y = 0000
# Out:
#   Cell In[63], line 3
#     x | y = 1111
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
x= 1010#10
y= o0101#5
x | y = 1111
x & y = 0000

# %%
x=10
y=5
x|y
# Out:
# 15

# %%
x&y
# Out:
# 0

# %%
x=int(input('enter the grade marks'))
# Out:
# enter the grade marks 72

# %%
x
# Out:
# 72

# %%
if x<=25:
    print('fail')
elif x<=44 and x>25:
    print('E')
elif x>=45 and x<=49:
   print('D')
elif x>=50 and x<=59:
    print('C')
elif x>=60 and x<=79:
    print('B')
elif x>=80 and x<=89:
    print('A')
else:
   print('A+')
# Out:
# B

# %%
image

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 5956-4A1A
#
#  Directory of C:\Users\User\Downloads\60 days of python
#
# 03/08/2025  07:36 PM    <DIR>          .
# 03/08/2025  07:36 PM    <DIR>          ..
# 03/07/2025  11:12 AM    <DIR>          .ipynb_checkpoints
# 03/08/2025  12:10 AM            10,618 day2.ipynb
# 03/07/2025  12:20 PM            16,515 day3.ipynb
# 03/08/2025  07:36 PM            33,261 day4.ipynb
#                3 File(s)         60,394 bytes
#                3 Dir(s)  104,329,940,992 bytes free

# %% [markdown]
# ![]{ml.JPG}

# %%
from IPython.display import Image #ipython.display consists of video,audio and images 
Image('qs.png')

# %%
x=int(input('enter the units'))
# Out:
# enter the units 245

# %%
x=int(input('enter the units'))
if x<=100:
    print('No charge')
elif x>100 and x<=200:
    y=(x-100)*5
    print('charge amount {}'.format(y))
    
    
else :
    z=(x-200)*10+500
    print('charge amount {} rupees'.format(z))
# Out:
# enter the units 350
# charge amount 2000 rupees

# %%
#improting the relevant modules
import matplotlib.pyplot as plt
import math
A=100
w=2*3.1416*(1/20)
t=[x for x in range(100)]
x=[A*math.sin(w*i) for i in t]
y=[7,12,21,200]
plt.plot(t,x,c='red',linewidth=2,label='line1',marker='o')
x2=[1,3,51,3]
y2=[7,12,21,200]
plt.plot(y2,x2,c='green',label='line2',marker='o',markerfacecolor='orange')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend()
plt.xlim(-0,20)
plt.ylim(-100,100)
# Out:
# (-100.0, 100.0)

# %%
x=[1,4,5
   1,35,6
   1,4,5]
# Out:
#   Cell In[1], line 1
#     x=[1,4,5
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
